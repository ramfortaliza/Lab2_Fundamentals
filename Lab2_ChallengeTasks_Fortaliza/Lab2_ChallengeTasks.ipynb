# %%
target_name = "FORTALIZA"
SEED_NUM = 6
redacted_name =""

for char in target_name:
    if char in "AEIOU":
        redacted_name += str(SEED_NUM)
    else:
        redacted_name += char

    print("Original Surname:", target_name)
    print("SEED_NUM Used:", SEED_NUM)
    print("Redacted Output", redacted_name)
    break
# Out:
# Original Surname: FORTALIZA
# SEED_NUM Used: 6
# Redacted Output F

# %%
ENGINEER = "FORTALIZA"     
STUDENT_ID = "TUPM-25-0186" 
SEED_NUM = int(STUDENT_ID[-1])

first_letter = ENGINEER[0]
ascii_val = ord(first_letter)

total_loops = SEED_NUM + 3

verification_hash = (ascii_val * SEED_NUM) - total_loops

print("--- ASSESSMENT DATA FOR EXERCISE 2 ---")
print(f"First Letter ASCII (A): {ascii_val}")
print(f"SEED_NUM (B): {SEED_NUM}")
print(f"Total Loops (C): {total_loops}")
print(f"Verification Hash: {verification_hash}")
print("Completed.")
# Out:
# --- ASSESSMENT DATA FOR EXERCISE 2 ---
# First Letter ASCII (A): 70
# SEED_NUM (B): 6
# Total Loops (C): 9
# Verification Hash: 411

# %%
correct_password = "FortalizaRam" 
attempts = 0
input_matches = False

while not input_matches:
    user_input = input("Enter password to unlock system: ")
    attempts += 1
    
    if user_input == correct_password:
        print("System Unlocked.")
        input_matches = True
    else:
        print("Incorrect password. Please try again.")

print(f"Attempts before success: {attempts}")
# Out:
# Incorrect password. Please try again.
# System Unlocked.
# Attempts before success: 2
